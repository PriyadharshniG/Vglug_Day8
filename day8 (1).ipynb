# %%
text="Priyadharshni"

# %%
text1='Priya dharshni'

# %%
text2="""This is a
multi line string"""

# %%
print(text)
print(text1)
print(text2)
# Out:
# Priyadharshni
# Priya
# This is a
# multi line string

# %% [markdown]
# **len() Function**

# %%
print(len(text))
print(text[12])
# Out:
# 13
# i

# %% [markdown]
# **Case** **Conversion**

# %%
print(text.upper())
print(text.lower())
print(text1.capitalize())
print(text1.title())
print(text.isalpha())
print(text.isdigit())
print(text.isalnum())
# Out:
# PRIYADHARSHNI
# priyadharshni
# Priya dharshni
# Priya Dharshni
# True
# False
# True

# %%
print(text[0:])
# Out:
# Priyadharshni

# %% [markdown]
# **Slicing**

# %%
a="Hello world , this is python"

# %%
print(a[4])
print(a[1:7])
print(a[0:8])
print(a[:8])
# Out:
# o
# ello w
# Hello wo
# Hello wo

# %% [markdown]
# **Negative Indexing**

# %%
print(a[-8:-3])
# Out:
# s pyt

# %%
b="I love 'Python' programminng"
print(b)
# Out:
# I love 'Python' programminng

# %%
c="I love \"Java\" programming"
print(c)
# Out:
# I love "Java" programming

# %% [markdown]
# **String Formatting**

# %%
name="Priya"
age=20
print(f"My name is {name},I am {age} years old")
# Out:
# My name is Priya,I am 20 years old

# %% [markdown]
# **.format()**

# %%
print("My name is {},I am {} years old".format(name,age))
# Out:
# My name is Priya,I am 20 years old

# %% [markdown]
# **Old method**

# %%
print("My name is %s,I am %d years old"%(name,age))
# Out:
# My name is Priya,I am 20 years old
